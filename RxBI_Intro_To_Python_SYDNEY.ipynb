# %% [markdown]
# <a href="https://colab.research.google.com/github/sydneywaskin/learning/blob/main/RxBI_Intro_To_Python_SYDNEY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Python for Data Analysts
#
# This notebook contains an introductory lesson to python for data analysts.  For questions please contact brittany_campos@premierinc.com
#
#
# You can find the example files [here](https://premierinc.sharepoint.com/teams/PharmacyBIAnalyticsSolutionHub/Shared%20Documents/Forms/AllItems.aspx?id=%2Fteams%2FPharmacyBIAnalyticsSolutionHub%2FShared%20Documents%2FGeneral%2FRxBI%20Lunch%20%26%20Learn&viewid=ebc24d07%2D9419%2D43f6%2D811c%2D927370ddfc3c)

# %% [markdown]
# ## Getting Started

# %% [markdown]
# We will be using Colab, a google tool that provides you with "a computer in the cloud" that you can immmediately write and run code on.

# %% [markdown]
# Python is a powerful programming language that can be used to create complex applications (like Spotify!) or just to do some basic data cleaning.
#
# Here are some basic concepts we will discuss to assist you as we work on analysis today!
#
# 1. Commenting
# 2. Variables
# 3. Data Types, Lists, Dictionaries
# 4. Functions / Methods

# %%
# You can leave a comment in Python by simply placing a hash mark in front of the text.  It is considered a best practice to comment your code well.

# %% [markdown]
# #### Variables

# %% [markdown]
# A variable is a placeholder for information.  Variables have a variable name, and they have a value that they are assigned.
#
# A variable can be assigned a value that is a number, a set of charachters (like a word, or sentence!), a file, or even more complicated types of data!

# %%
# Let's create a variable named "x" and assign it a value of 1.
x = 1

# Now let's create a variable named "y" and assign it a value of -1
y = -1

# Now, let's create a THIRD variable and name it "z"; we will make z equal to the value of variable x plus variable y.
# Yes, we can do math with our variables!
z = x + y

# Using the print function we can let Colab and python do the calculation, and return the value now stored in z.
print(z)
# Out:
# 0

# %% [markdown]
# #### Intro to Data Types

# %% [markdown]
# When you use any computer program it is storing information in variables, and that information must have a type, which dictates what can be done with it.
#
# This is how the last cell knew to perform addition - it understood both x and y to be numbers, and it has methods of handling numbers and performing mathmatic equations.
#
# There are MANY types of data, and you can even create custom data types.  Today we will focus on the most important for basic data analysis.

# %%
# A String is a type of data that consists of text.  It could be one letter, or many. It could be plain text, symbols, or numbers.
# A String is declared within quotation marks, such as '' or "".  You can use either, but they cannot be mixed and matched indiscrimiately.

# Examples of Strings in Python
name = "Brittany Campos"
title = "Pharmacy Analyst"
seperator = " | "

# Strings can be concatenated, or added, together
signature = name + seperator + title

print(signature)
# Out:
# Brittany Campos | Pharmacy Analyst

# %%
# the combination of '\n' in Python declares a new line in your text.
print(name + '\n' + title)
# Out:
# Brittany Campos
# Pharmacy Analyst

# %%
# You can insert variables into placeholders to dynamically create text
print(f"{name} is a talented and amazing {title} - Happy Work-a-versary!")
# Out:
# Brittany Campos is a talented and amazing Pharmacy Analyst - Happy Work-a-versary!

# %% [markdown]
# When you need to perform math, you will want to use a numeric data type.  There are different ways that computers, and python, think about numbers.  Today, again, we will focus on the most common for our use cases as an analyst.

# %%
# Integers are whole numbers
x = 1
y = 0
z = -1

# Numbers can be used in math equations, from very simple, to very complex.
integers = x + y + z
print(integers)
# Out:
# 0

# %%
# Floats are fractional numbers in a decimal format - but they are not 100% precise.
x = 1.0
y = 0.25
z = -1.789
a = 0.0

floats = x + y + z + a
print(floats)
# Out:
# -0.5389999999999999

# %%
# When you are performing precise mathmatical calculations, often with currency for for medical/engineering applications, you may want to use a Decimal
# the Decimal data type is not supported in all libraries, but we can use it if required
from decimal import Decimal
x = Decimal('1.00')
y = Decimal('0.25')
z = Decimal('-1.789')

decimals = x + y + z
print(decimals)
# Out:
# -0.539

# %% [markdown]
# Dates and Times are often important in analysis; there are special data types that can be used to handle these types of data.  This is another subject which can be simple, or complex, depending on your data and use case.  We will focus on the basics today.

# %%
# Importing the datetime library can help manage dates and times
import datetime as dt

# Example datetime variable
date = dt.datetime(2023, 1, 1)
print(date)
# Out:
# 2023-01-01 00:00:00

# %% [markdown]
# Often you will have dates in a non-date format, some form of text, and will need to convert it to a datetime format so that you can perform analysis on it appropriately - such as charting it over time, or performing math on the dates.

# %%
date = "2023-05-13"

# coerce to datetime
date = dt.datetime.strptime(date, '%Y-%m-%d')
print(date)
# Out:
# 2023-05-13 00:00:00

# %%
date = "05/06/2025"

# Coerce to datetime
date = dt.datetime.strptime(date, '%m/%d/%Y')
print(date)
# Out:
# 2025-05-06 00:00:00

# %%
date = "JAN-23"

# Coerce to datetime
date = dt.datetime.strptime(date, '%b-%y')
print(date)
# Out:
# 2023-01-01 00:00:00

# %%
date = "JAN-2023"

# Coerce to datetime
date = dt.datetime.strptime(date, '%b-%Y')
print(date)
# Out:
# 2023-01-01 00:00:00

# %%
# We can even perform math on dates
order_date = dt.datetime(2023, 1, 1)
shipment_date = dt.datetime(2023, 1, 3)
delivery_date = dt.datetime(2023, 1, 5)

time_to_ship = shipment_date - order_date
time_to_deliver = delivery_date - shipment_date

print(time_to_ship)
print(time_to_deliver)
# Out:
# 2 days, 0:00:00
# 2 days, 0:00:00

# %%
# We can also call today's date, or right now's time
now = dt.datetime.now()
print(now)
# Out:
# 2025-05-16 19:04:24.764371

# %%
# And then we can use "now" to perform dynamic logic - like determine what % of the year is complete based on a week count for a pace band
percent_complete = now.isocalendar()[1] / 52
print(percent_complete)

# Or we can count what week number we are on today
print(now.isocalendar()[1])

# Or we can get today's date
now = dt.datetime.now()
print(now)

# or just today's date
print(now.date())

# Or we can find out yesterday's date by decrementing today's date which is stored in variable now
yesterday = now - dt.timedelta(days=1)
print(yesterday)
# Out:
# 0.38461538461538464
# 20
# 2025-05-16 19:04:23.478361
# 2025-05-16
# 2025-05-15 19:04:23.478361

# %% [markdown]
# There are even data types designed to store multiple pieces of information, we will learn about two now, and a third more powerful later.

# %%
# A list allows you to store - a list - of information as a list of comma seperated values.
# They use square brackets on the outside
list = ["a", "b", "c"]
print(list)

numberslist = [1, 2, 3, 4, 5]
print(numberslist)

# A dictionary allows you to store key-value pairs - pieces of information in a set.
# They use curly braces, each line has two values in quotes, and a colon between. The lines are seperated by commas.
dictionary = {"a": 1, "b": 2, "c": 3}
print(dictionary)
# Out:
# ['a', 'b', 'c']
# [1, 2, 3, 4, 5]
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# #### Methods and Functions

# %% [markdown]
# A function, in code, is like math - its a template. You put value(s) in, and you get value(s) out.
#
# A method is the name of a function that is in a library you are using.  So not all functions are methods, but all methods are functions.
#
# When we import a library, we call and use the methods (functions) it contains.  We can also create our own custom functions.

# %%
# When we performed the datetime calculations, we were calling the datetime library using it's nickname, dt, that we assigned earlier.
# Then, we added a '.' and the name of the method we want to use.
# The method is followed by ()
# Within the () we place the arguments, or parameters, that the function needs to provide an answer. These are inputs.
now = dt.datetime.now()
print(now)

# In the example above, dt is the alias for our library, datetime
# .datetime.now() calls the datetime.now() method, which has no arguments.  It just returns today's date and time.
# Out:
# 2025-05-16 19:04:19.463558

# %%
# We can create our own functions, which lets us write code that can be reused over and over.
# Think of a function like a template or blueprint.
# The syntax is "def " followed by the function name and ().
# within the () you will list the parameter names and their data types.
# You will end that line with a :
# Then, declare your code
# Then, you can use "return" keyword to have the function return a value.

def function(qty: float, price: float):
  total = qty * price
  return total

# Example Use
total = function(10, 20)
print(total)
# Out:
# 200

# %% [markdown]
# ### Importing and Installing Packages

# %% [markdown]
# "We stand on the shoulder of giants."
#
# In programming, we often use "libraries" of code that are written by others.  Colab has Python, and many of it's public libraries, already installed - we just need to import them before we can use them!
#
# *What We're Using*
# - Pandas is a popular library used for reading and manipulating tabular data, such as a spreadsheet or database table.
# - Pandas GBQ is a Google companion to Pandas that makes interacting with BigQuery easier.
# - Pandera is a library for validating data that can be used with Pandas

# %%
# Some libraries, like Pandera, are not installed in Colab by default - but you can install them by using keyword "!pip" in front of the package name
# !pip install pandera

# %%
# Import libraries by using the keyword "import" followed by the name of the package, and then provide an alias you can call in your code later.
import pandas as pd
import pandas_gbq as gbq
import pandera as pa

# %%
# Set display options to show all rows and columns; helpful if you have long names or large datasets.
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Reading Data

# %% [markdown]
# There are many ways you can get data into Colab so that you can use python to read or transform it.
#
# 1. Files -- You can import files or entire folders of files, Colab gives you 70GB of space!
#
# 2.  BigQuery -- you can connect easily to BigQuery and return data via a SQL query.
#
# 3. Other Databases -- there are python based tools that can be used to access data in other types of databases, though our network security may pose a challenge.
#
# 4. Create Data -- you can type data directly into Python/Colab when appropriate.

# %% [markdown]
# ### Reading Files

# %%
# Read a csv into a pandas dataframe; a dataframe is another type of data - or data type!
csv = pd.read_csv('example_csv.csv')

# Preview the dataframe by using the .head() method
csv.head()
# Out:
#            ndc  production_status  start_date
# 0  70004043009  Active Production  2025-05-06
# 1  70004043012  Active Production  2025-05-06
# 2  63037010005  Active Production  2025-05-06
# 3  63037010010       Discontinued  2025-05-06
# 4  63037010105  Active Production  2025-05-06

# %%
# Read an xls or xlsx into a pandas dataframe
excel = pd.read_excel('example_xlsx.xlsx')

# Preview the dataframe by using the .head() method
excel.head()
# Out:
#   GCDF        DOSE            GCDF_DESC
# 0   AA     AEROSOL         AEROSOL (ML)
# 1   AB     AEROSOL       AEROSOL (GRAM)
# 2   AC     AEROSOL         AEROSOL (EA)
# 3   AD  AER REFILL  AEROSOL REFILL (ML)
# 4   AE  AER REFILL  AEROSOL REFILL (EA)

# %%
# There are ways to enhance the read of the file to fit different use cases.  These are my favorites.

# Read in the entire dataset as strings, to ensure it's a literal translation of the data and there are no encoding issues
strings = pd.read_csv("example_csv.csv", dtype=str)

# Read in the dataset but skip the first few rows
skiprows = pd.read_excel("skiprows_example.xls", dtype=str, sheet_name=1, skiprows=1)
skiprows.head()
# Out:
#   Credit UID Month-YR System ID                    System Name Facility ID  \
# 0   22678581   APR-22    NC0180  WATAUGA MEDICAL CENTER, INC.       NC0180
# 1   22678628   APR-22    NC0180  WATAUGA MEDICAL CENTER, INC.       NC0180
# 2   22678629   APR-22    NC0180  WATAUGA MEDICAL CENTER, INC.       NC0180
# 3   22678630   APR-22    NC0180  WATAUGA MEDICAL CENTER, INC.       NC0180
# 4   22678631   APR-22    NC0180  WATAUGA MEDICAL CENTER, INC.       NC0180
#
#                   Facility Name          Contracting Member Facility DEA#  \
# 0  WATAUGA MEDICAL CENTER, INC.  WATAUGA MEDICAL CENTER INC     AW3203128
# 1  WATAUGA MEDICAL CENTER, INC.  WATAUGA MEDICAL CENTER INC     AW3203128
# 2  WATAUGA MEDICAL CENTER, INC.  WATAUGA MEDICAL CENTER INC     AW3203128
# 3  WATAUGA MEDICAL CENTER, INC.  WATAUGA MEDICAL CENTER INC     AW3203128
# 4  WATAUGA MEDICAL CENTER, INC.  WATAUGA MEDICAL CENTER INC     AW3203128
#
#    Facility Address Facility Address Secondary Facility City Facility State  \
# 0  336 DEERFIELD RD                        NaN         BOONE             NC
# 1  336 DEERFIELD RD                        NaN         BOONE             NC
# 2  336 DEERFIELD RD                        NaN         BOONE             NC
# 3  336 DEERFIELD RD                        NaN         BOONE             NC
# 4  336 DEERFIELD RD                        NaN         BOONE             NC
#
#   Facility Zip Code                      Rep Wholesaler Cust Account Num  \
# 0        28607-5008  AmerisourceBergen Drug Corporation        100076169
# 1        28607-5008  AmerisourceBergen Drug Corporation        100076169
# 2        28607-5008  AmerisourceBergen Drug Corporation        100076169
# 3        28607-5008  AmerisourceBergen Drug Corporation        100076169
# 4        28607-5008  AmerisourceBergen Drug Corporation        100076169
#
#   Contract NDC  Contracted Supplier  Contract No Pkg Size Pkg Qty  \
# 0  45802006070       PADAGIS US LLC  PPPH18PER01      144       1
# 1  67457052810  MYLAN INSTITUTIONAL  PPPH18UDL01        1       1
# 2  67457053035  MYLAN INSTITUTIONAL  PPPH18UDL01        1       1
# 3  67457053035  MYLAN INSTITUTIONAL  PPPH18UDL01        1       1
# 4  67457053035  MYLAN INSTITUTIONAL  PPPH18UDL01        1       1
#
#   Rep Invoice Date Rep Invoice Num      Rep NDC     Rep Supplier  \
# 0        4/11/2022      3089199742  68001047748  BLUEPOINT LABOR
# 1        4/16/2022      3089858003  68001041636  BLUEPOINT LABOR
# 2         4/8/2022      3089008792  00143955201  WEST-WARD/HIKMA
# 3        4/12/2022      3089324802  00143955201  WEST-WARD/HIKMA
# 4        4/19/2022      3090052580  00143955201  WEST-WARD/HIKMA
#
#        Rep Brand Name    Rep Generic Name Rep Package Size  \
# 0          BACITRACIN          BACITRACIN              144
# 1  LEUCOVORIN CALCIUM  LEUCOVORIN CALCIUM                1
# 2  LEUCOVORIN CALCIUM  LEUCOVORIN CALCIUM                1
# 3  LEUCOVORIN CALCIUM  LEUCOVORIN CALCIUM                1
# 4  LEUCOVORIN CALCIUM  LEUCOVORIN CALCIUM                1
#
#   Rep Package Quantity Rep Invoice Price Premier Contract Price Rep Sales Qty  \
# 0                    1             16.62                  16.42             1
# 1                    1              7.19                   5.07             4
# 2                    1             14.25                  12.48             1
# 3                    1             14.25                  12.48             1
# 4                    1             14.25                  12.48             1
#
#   Rep Sales Credit Request FTS Credit _ Amount Supplier Approved  \
# 0     16.62            0.2                                  0.19
# 1     28.76           8.48                                  5.07
# 2     14.25           1.77                                  1.77
# 3     14.25           1.77                                  1.77
# 4     14.25           1.77                                  1.77
#
#         Rejected Amount                   Rejection Reason  \
# 0  0.010000000000000009          USED WAC PRICE LIMITATION
# 1                  3.41  LIMITED TO 120% OF CONTRACT PRICE
# 2                     0                       PAID IN FULL
# 3                     0                       PAID IN FULL
# 4                     0                       PAID IN FULL
#
#   # Days to reconciled FTS Credit Issued July 2023  \
# 0                  389                       0.152
# 1                  389                       4.056
# 2                  389                       1.416
# 3                  389                       1.416
# 4                  389                       1.416
#
#                  Crediting Wholesaler Crediting Account  \
# 0  AmerisourceBergen Drug Corporation        0100076169
# 1  AmerisourceBergen Drug Corporation        0100076169
# 2  AmerisourceBergen Drug Corporation        0100076169
# 3  AmerisourceBergen Drug Corporation        0100076169
# 4  AmerisourceBergen Drug Corporation        0100076169
#
#   Credit Reference Number
# 0               354286787
# 1               354286787
# 2               354286787
# 3               354286787
# 4               354286787

# %%
# When handling Excel files, you may need to access a sheet by name
sheet = pd.read_excel("skiprows_example.xls", sheet_name="Facilities")

# or maybe by sheet number
sheet = pd.read_excel("skiprows_example.xls", sheet_name=1)
sheet.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0  Credit UID   Month-YR  System ID
# 1    22678581     APR-22     NC0180
# 2    22678628     APR-22     NC0180
# 3    22678629     APR-22     NC0180
# 4    22678630     APR-22     NC0180
#
#   PREMIER MEMBER\nFailure to Supply (FTS)\nCREDITS 2023-07-15 00:00:00  \
# 0                                      System Name         Facility ID
# 1                    WATAUGA MEDICAL CENTER, INC.               NC0180
# 2                    WATAUGA MEDICAL CENTER, INC.               NC0180
# 3                    WATAUGA MEDICAL CENTER, INC.               NC0180
# 4                    WATAUGA MEDICAL CENTER, INC.               NC0180
#
#                        1585.304                  Unnamed: 6     Unnamed: 7  \
# 0                 Facility Name          Contracting Member  Facility DEA#
# 1  WATAUGA MEDICAL CENTER, INC.  WATAUGA MEDICAL CENTER INC      AW3203128
# 2  WATAUGA MEDICAL CENTER, INC.  WATAUGA MEDICAL CENTER INC      AW3203128
# 3  WATAUGA MEDICAL CENTER, INC.  WATAUGA MEDICAL CENTER INC      AW3203128
# 4  WATAUGA MEDICAL CENTER, INC.  WATAUGA MEDICAL CENTER INC      AW3203128
#
#          Unnamed: 8                  Unnamed: 9    Unnamed: 10  \
# 0  Facility Address  Facility Address Secondary  Facility City
# 1  336 DEERFIELD RD                         NaN          BOONE
# 2  336 DEERFIELD RD                         NaN          BOONE
# 3  336 DEERFIELD RD                         NaN          BOONE
# 4  336 DEERFIELD RD                         NaN          BOONE
#
#       Unnamed: 11        Unnamed: 12                         Unnamed: 13  \
# 0  Facility State  Facility Zip Code                      Rep Wholesaler
# 1              NC         28607-5008  AmerisourceBergen Drug Corporation
# 2              NC         28607-5008  AmerisourceBergen Drug Corporation
# 3              NC         28607-5008  AmerisourceBergen Drug Corporation
# 4              NC         28607-5008  AmerisourceBergen Drug Corporation
#
#         Unnamed: 14   Unnamed: 15          Unnamed: 16  Unnamed: 17  \
# 0  Cust Account Num  Contract NDC  Contracted Supplier  Contract No
# 1         100076169   45802006070       PADAGIS US LLC  PPPH18PER01
# 2         100076169   67457052810  MYLAN INSTITUTIONAL  PPPH18UDL01
# 3         100076169   67457053035  MYLAN INSTITUTIONAL  PPPH18UDL01
# 4         100076169   67457053035  MYLAN INSTITUTIONAL  PPPH18UDL01
#
#   Unnamed: 18 Unnamed: 19       Unnamed: 20      Unnamed: 21  Unnamed: 22  \
# 0    Pkg Size     Pkg Qty  Rep Invoice Date  Rep Invoice Num      Rep NDC
# 1         144           1         4/11/2022       3089199742  68001047748
# 2           1           1         4/16/2022       3089858003  68001041636
# 3           1           1          4/8/2022       3089008792  00143955201
# 4           1           1         4/12/2022       3089324802  00143955201
#
#        Unnamed: 23         Unnamed: 24         Unnamed: 25       Unnamed: 26  \
# 0     Rep Supplier      Rep Brand Name    Rep Generic Name  Rep Package Size
# 1  BLUEPOINT LABOR          BACITRACIN          BACITRACIN               144
# 2  BLUEPOINT LABOR  LEUCOVORIN CALCIUM  LEUCOVORIN CALCIUM                 1
# 3  WEST-WARD/HIKMA  LEUCOVORIN CALCIUM  LEUCOVORIN CALCIUM                 1
# 4  WEST-WARD/HIKMA  LEUCOVORIN CALCIUM  LEUCOVORIN CALCIUM                 1
#
#             Unnamed: 27        Unnamed: 28             Unnamed: 29  \
# 0  Rep Package Quantity  Rep Invoice Price  Premier Contract Price
# 1                     1              16.62                   16.42
# 2                     1               7.19                    5.07
# 3                     1              14.25                   12.48
# 4                     1              14.25                   12.48
#
#      Unnamed: 30 Unnamed: 31     Unnamed: 32  \
# 0  Rep Sales Qty   Rep Sales  Credit Request
# 1              1       16.62             0.2
# 2              4       28.76            8.48
# 3              1       14.25            1.77
# 4              1       14.25            1.77
#
#                              Unnamed: 33      Unnamed: 34  \
# 0  FTS Credit _ Amount Supplier Approved  Rejected Amount
# 1                                   0.19             0.01
# 2                                   5.07             3.41
# 3                                   1.77                0
# 4                                   1.77                0
#
#                          Unnamed: 35           Unnamed: 36  \
# 0                   Rejection Reason  # Days to reconciled
# 1          USED WAC PRICE LIMITATION                   389
# 2  LIMITED TO 120% OF CONTRACT PRICE                   389
# 3                       PAID IN FULL                   389
# 4                       PAID IN FULL                   389
#
#                    Unnamed: 37                         Unnamed: 38  \
# 0  FTS Credit Issued July 2023                Crediting Wholesaler
# 1                        0.152  AmerisourceBergen Drug Corporation
# 2                        4.056  AmerisourceBergen Drug Corporation
# 3                        1.416  AmerisourceBergen Drug Corporation
# 4                        1.416  AmerisourceBergen Drug Corporation
#
#          Unnamed: 39              Unnamed: 40
# 0  Crediting Account  Credit Reference Number
# 1         0100076169                354286787
# 2         0100076169                354286787
# 3         0100076169                354286787
# 4         0100076169                354286787

# %% [markdown]
# ### Query BigQuery

# %%
# Write your query as a string
# Select statement is the exact one we would use in Big Query

query = """
SELECT * FROM `pharmacybi-dev.pgx_mart.slvr_product_family`
"""
# Use the GBQ library and the read_gbq method to extract data using the arguments query and project_id
# Project id is wherever you want it to go into
extract = gbq.read_gbq(query, project_id='pharmacybi-dev')
extract.head()

# extract.head() shows the firs few lines of output, can also put a number in () if you want to see a specific row number
# Out:
# Downloading: 100%|██████████|
#    seller                generic_name dosage_form  product_volume  uom_detail  \
# 0  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
# 1  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0          25
# 2  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
# 3  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0          25
# 4  AMNEAL        POTASSIUM PHOSPHATES        VIAL             5.0           5
#
#            ndc fff_item_code              product_family
# 0  70121157301     MET157301  Methylprednisolone Acetate
# 1  70121157305     MET157305  Methylprednisolone Acetate
# 2  70121157401     MET157401  Methylprednisolone Acetate
# 3  70121157405     MET157405  Methylprednisolone Acetate
# 4  80830169303     POT169303        Potassium Phosphates

# %%
mtd_query = """
SELECT * FROM `pharmacybi-dev.pgx_mart.slvr_fff_mtd`
"""

mtd = gbq.read_gbq(mtd_query, project_id='pharmacybi-dev')
mtd.head()
# Out:
# Downloading: 100%|██████████|
#                    fff_facility_name fff_facility_id  \
# 0  Jefferson Regional Medical Center        FAR00030
# 1  Jefferson Regional Medical Center        FAR00030
# 2  Jefferson Regional Medical Center        FAR00030
# 3  Jefferson Regional Medical Center        FAR00030
# 4        Verde Valley Medical Center        FAZ00561
#
#             fff_health_system_name fff_health_system_id fff_item_number  \
# 0   JEFFERSON REGIONAL MED CTR PGX           ML00374896       AMI987525
# 1   JEFFERSON REGIONAL MED CTR PGX           ML00374896       AMI987525
# 2   JEFFERSON REGIONAL MED CTR PGX           ML00374896       AMI987525
# 3   JEFFERSON REGIONAL MED CTR PGX           ML00374896       AMI987525
# 4  NORTHERN ARIZONA HEALTHCARE PGX           ML00380828       AMI987525
#
#                    fff_item_description firm_allocations_indicator  \
# 0  AMIODARONE HCL 150MG/3ML 25-PK-HIKMA                          F
# 1  AMIODARONE HCL 150MG/3ML 25-PK-HIKMA                          F
# 2  AMIODARONE HCL 150MG/3ML 25-PK-HIKMA                          F
# 3  AMIODARONE HCL 150MG/3ML 25-PK-HIKMA                          F
# 4  AMIODARONE HCL 150MG/3ML 25-PK-HIKMA                          F
#
#   regional_director territory_manager            sdr valid_start_date  \
# 0    Robert Grzenda        Judy Davis  Justin Ground       2025-01-01
# 1    Robert Grzenda        Judy Davis  Justin Ground       2025-01-01
# 2    Robert Grzenda        Judy Davis  Justin Ground       2025-01-01
# 3    Robert Grzenda        Judy Davis  Justin Ground       2025-01-01
# 4    Terri St. John         Ken Engle           Open       2025-01-01
#
#              ndc  annual_commitment  monthly_allocation  monthly_remaining  \
# 0  00143-9875-25                 72                   9                  9
# 1  00143-9875-25                 72                   9                  9
# 2  00143-9875-25                 72                   9                  9
# 3  00143-9875-25                 72                   9                  9
# 4  00143-9875-25                 12                   1                  1
#
#    ytd_total  percent_compliant  actual_purchased_units purchase_month
# 0          0               0.00                    <NA>     2025-01-01
# 1          0               0.00                    <NA>     2025-02-01
# 2          0               0.00                    <NA>     2025-03-01
# 3          0               0.00                    <NA>     2025-04-01
# 4          4              33.33                       1     2025-01-01

# %% [markdown]
# ## Viewing The Data

# %% [markdown]
# Once your data is in Colab, you probably want to be able to look at it and understand it quickly.  Here are some of my favorite quick ways to view and assess my data.

# %%
# View the first few rows; if you include a number, it will provide that many rows.
extract.head(1)
# Out:
#    seller                generic_name dosage_form  product_volume  uom_detail  \
# 0  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
#
#            ndc fff_item_code              product_family
# 0  70121157301     MET157301  Methylprednisolone Acetate

# %%
# view the entire dataset as a formatted table in Colab
extract
# Out:
#                         seller                          generic_name  \
# 0                       AMNEAL            METHYLPREDNISOLONE ACETATE
# 1                       AMNEAL            METHYLPREDNISOLONE ACETATE
# 2                       AMNEAL            METHYLPREDNISOLONE ACETATE
# 3                       AMNEAL            METHYLPREDNISOLONE ACETATE
# 4                       AMNEAL                  POTASSIUM PHOSPHATES
# 5                       AMNEAL                  POTASSIUM PHOSPHATES
# 6                       AMNEAL                  POTASSIUM PHOSPHATES
# 7                    AMPHASTAR                      ATROPINE SULFATE
# 8                    AMPHASTAR                      CALCIUM CHLORIDE
# 9                    AMPHASTAR                DEXTROSE 50 % IN WATER
# 10                   AMPHASTAR                           EPINEPHRINE
# 11                   AMPHASTAR                      LIDOCAINE HCL/PF
# 12                   AMPHASTAR                 PHYTONADIONE (VIT K1)
# 13                   AMPHASTAR                    SODIUM BICARBONATE
# 14                      APOTEX                      CEFAZOLIN SODIUM
# 15                      APOTEX                      CEFAZOLIN SODIUM
# 16                      APOTEX                      CEFAZOLIN SODIUM
# 17                      APOTEX                      CEFAZOLIN SODIUM
# 18                      APOTEX                          CEFEPIME HCL
# 19                      APOTEX                          CEFEPIME HCL
# 20                      APOTEX                          CEFEPIME HCL
# 21                      APOTEX                          CEFEPIME HCL
# 22                      APOTEX                    CEFTRIAXONE SODIUM
# 23                      APOTEX                    CEFTRIAXONE SODIUM
# 24                      BAXTER         DEXMEDETOMIDINE IN 0.9 % NACL
# 25                      BAXTER         DEXMEDETOMIDINE IN 0.9 % NACL
# 26                      BAXTER                            METOPROLOL
# 27   ENDO INJECTABLE SOLUTIONS                    PITOCIN (OXYTOCIN)
# 28   ENDO INJECTABLE SOLUTIONS                    PITOCIN (OXYTOCIN)
# 29                       EXELA                       CUPRIC CHLORIDE
# 30                       EXELA                      CYSTEINE (ELCYS)
# 31                       EXELA                     POTASSIUM ACETATE
# 32                       EXELA               SODIUM BICARBONATE 8.4%
# 33                       EXELA                         ZINC CHLORIDE
# 34              FRESENIUS KABI                            BUMETANIDE
# 35              FRESENIUS KABI                            BUMETANIDE
# 36              FRESENIUS KABI  BUPIVACAINE HCL 0.25%/EPINEPHRINE/PF
# 37              FRESENIUS KABI              BUPIVACAINE HCL 0.25%/PF
# 38              FRESENIUS KABI              BUPIVACAINE HCL 0.25%/PF
# 39              FRESENIUS KABI   BUPIVACAINE HCL 0.5%/EPINEPHRINE/PF
# 40              FRESENIUS KABI               BUPIVACAINE HCL 0.5%/PF
# 41              FRESENIUS KABI               BUPIVACAINE HCL 0.5%/PF
# 42              FRESENIUS KABI                             CISPLATIN
# 43              FRESENIUS KABI                             CISPLATIN
# 44              FRESENIUS KABI                             CISPLATIN
# 45              FRESENIUS KABI                              DIAZEPAM
# 46              FRESENIUS KABI                   DIPHENHYDRAMINE HCL
# 47              FRESENIUS KABI                   DIPHENHYDRAMINE HCL
# 48              FRESENIUS KABI                   FENTANYL CITRATE/PF
# 49              FRESENIUS KABI                          FLUOROURACIL
# 50              FRESENIUS KABI                          FLUOROURACIL
# 51              FRESENIUS KABI                          FLUOROURACIL
# 52              FRESENIUS KABI                          FLUOROURACIL
# 53              FRESENIUS KABI        HEPARIN SOD,PORK IN 0.45% NACL
# 54              FRESENIUS KABI        HEPARIN SOD,PORK IN 0.45% NACL
# 55              FRESENIUS KABI                    HEPARIN SODIUM-D5W
# 56              FRESENIUS KABI                    HEPARIN SODIUM-D5W
# 57              FRESENIUS KABI                  HYDROMORPHONE HCL/PF
# 58              FRESENIUS KABI                  HYDROMORPHONE HCL/PF
# 59              FRESENIUS KABI                  HYDROMORPHONE HCL/PF
# 60              FRESENIUS KABI                  HYDROMORPHONE HCL/PF
# 61              FRESENIUS KABI                              KETAMINE
# 62              FRESENIUS KABI                              KETAMINE
# 63              FRESENIUS KABI                              KETAMINE
# 64              FRESENIUS KABI                      MORPHINE SULFATE
# 65              FRESENIUS KABI                      MORPHINE SULFATE
# 66              FRESENIUS KABI                  PROPOFOL (DIPRIVAN®)
# 67              FRESENIUS KABI                  PROPOFOL (DIPRIVAN®)
# 68              FRESENIUS KABI                  PROPOFOL (DIPRIVAN®)
# 69              FRESENIUS KABI                  PROPOFOL (DIPRIVAN®)
# 70              FRESENIUS KABI                          THIAMINE HCL
# 71              FRESENIUS KABI                             XYLOCAINE
# 72              FRESENIUS KABI            XYLOCAINE WITH EPINEPHRINE
# 73              FRESENIUS KABI            XYLOCAINE WITH EPINEPHRINE
# 74              FRESENIUS KABI            XYLOCAINE WITH EPINEPHRINE
# 75              FRESENIUS KABI                         XYLOCAINE-MPF
# 76              FRESENIUS KABI                         XYLOCAINE-MPF
# 77              FRESENIUS KABI                         XYLOCAINE-MPF
# 78              FRESENIUS KABI                         XYLOCAINE-MPF
# 79              FRESENIUS KABI                         XYLOCAINE-MPF
# 80                       HIKMA                        AMIODARONE HCL
# 81                       HIKMA                            DROPERIDOL
# 82                       HIKMA                            DROPERIDOL
# 83                       HIKMA                   FENTANYL CITRATE/PF
# 84                       HIKMA                   FENTANYL CITRATE/PF
# 85                       HIKMA                   FENTANYL CITRATE/PF
# 86                       HIKMA                   FENTANYL CITRATE/PF
# 87                       HIKMA                   FENTANYL CITRATE/PF
# 88                       HIKMA                             LORAZEPAM
# 89                       HIKMA                             LORAZEPAM
# 90                       HIKMA                             LORAZEPAM
# 91                       HIKMA                             LORAZEPAM
# 92                       HIKMA                        SODIUM ACETATE
# 93                       HIKMA                        SODIUM ACETATE
# 94                       HIKMA                 STERILE WATER FOR INJ
# 95                  LONG GROVE                              AK-FLUOR
# 96                  LONG GROVE         NOREPINEPHRINE BIT/0.9 % NACL
# 97                  LONG GROVE         NOREPINEPHRINE BIT/0.9 % NACL
# 98                  LONG GROVE         NOREPINEPHRINE BIT/0.9 % NACL
# 99                      PFIZER                 0.9 % SODIUM CHLORIDE
# 100                     PFIZER                 0.9 % SODIUM CHLORIDE
# 101                     PFIZER                              DIAZEPAM
# 102                     PFIZER         IBUTILIDE FUMARATE (CORVERT®)
# 103                     PFIZER                         LABETALOL HCL
# 104                     PFIZER                             LORAZEPAM
# 105                     PFIZER                   VINCRISTINE SULFATE
# 106                     PFIZER                   VINCRISTINE SULFATE
# 107                   SOMERSET         SULFAMETHOXAZOLE-TRIMETHOPRIM
# 108                   SOMERSET         SULFAMETHOXAZOLE-TRIMETHOPRIM
# 109                   SOMERSET         SULFAMETHOXAZOLE-TRIMETHOPRIM
# 110                       None                                  None
# 111                       None                                  None
# 112                       None                                  None
# 113                       None                                  None
# 114                       None                                  None
# 115                       None                                  None
#
#     dosage_form  product_volume  uom_detail          ndc fff_item_code  \
# 0          VIAL             1.0           1  70121157301     MET157301
# 1          VIAL             1.0          25  70121157305     MET157305
# 2          VIAL             1.0           1  70121157401     MET157401
# 3          VIAL             1.0          25  70121157405     MET157405
# 4          VIAL             5.0           5  80830169303     POT169303
# 5          VIAL            15.0          10  80830169102     POT169102
# 6          VIAL            50.0          10  80830169202     POT169202
# 7       SYRINGE            10.0          10  76329334001     ATR334001
# 8       SYRINGE            10.0          10  76329330401     CAL330401
# 9       SYRINGE            50.0          10  76329330201     DEX330201
# 10      SYRINGE            10.0          10  76329331801     EPI331801
# 11      SYRINGE             5.0          10  76329339001     LID339001
# 12      SYRINGE             0.5          10  76329124001     PHY124001
# 13      SYRINGE            50.0          10  76329335201     SOD335201
# 14         VIAL            10.0          25  60505614205     CEF614205
# 15         VIAL           100.0          10  60505614304     CEF614304
# 16         VIAL             1.0          25  60505623105     CEF623105
# 17         VIAL             1.0          25  60505626605     CEF626605
# 18         VIAL            20.0          10  60505614604     CEF614604
# 19         VIAL            20.0           1  60505614600     CEF614600
# 20         VIAL            20.0          10  60505614704     CEF614704
# 21         VIAL            20.0           1  60505614700     CEF614700
# 22         VIAL            20.0          10  60505614804     CEF614804
# 23         VIAL            20.0          10  60505614904     CEF614904
# 24   PLAST. BAG            50.0          24  00338955524     DEX955524
# 25   PLAST. BAG           100.0          12  00338955712     DEX955712
# 26         VIAL             5.0          10  36000003310     MET003310
# 27         VIAL             1.0          25  42023011625     PIT011625
# 28         VIAL            10.0          25  42023011602     PIT011602
# 29         VIAL            10.0          25  51754010304     CUP010304
# 30         VIAL            10.0          10  51754100703     ELC100703
# 31         VIAL           100.0          25  51754200404     POT200404
# 32         VIAL            50.0          25  51754500104     SOD500104
# 33         VIAL             1.0          25  51754010204     ZIN010204
# 34         VIAL             4.0          10  65219057004     BUM057004
# 35         VIAL            10.0          10  65219057210     BUM057210
# 36         VIAL            30.0          25  63323046837     SEN046837
# 37         VIAL            10.0          25  63323046417     SEN046417
# 38         VIAL            30.0          25  63323046437     SEN046437
# 39         VIAL            30.0          25  63323046237     SEN046237
# 40         VIAL            30.0          25  63323046637     SEN046637
# 41         VIAL            10.0          25  63323046617     SEN046617
# 42         VIAL            50.0           1  63323010351     CIS010351
# 43         VIAL           100.0           1  63323010365     CIS010365
# 44         VIAL           200.0           1  63323010364     CIS010364
# 45      SYRINGE             2.0          24  76045020420     DIA020420
# 46         VIAL             1.0          25  63323066401     DIP066401
# 47      SYRINGE             1.0          24  76045010210    DIP010210
# 48      SYRINGE             1.0          10  63323080811     FEN080811
# 49         VIAL            20.0          10  63323011720     FLR011720
# 50         VIAL            50.0           1  63323011751     FLR011751
# 51         VIAL           100.0           1  63323011761     FLR011761
# 52         VIAL            10.0          10  63323011710     FLR011710
# 53      IV SOLN           250.0          24  63323051774     HEP051774
# 54      IV SOLN           500.0          24  63323051877     HEP051877
# 55      IV SOLN           250.0          24  63323052374     HEP052374
# 56      IV SOLN           500.0          24  63323052277     HEP052277
# 57      SYRINGE             0.5          10  76045000906     DIL000906
# 58      SYRINGE             1.0          10  76045000911     DIL000911
# 59      SYRINGE             1.0          10  76045001011     DIL001011
# 60      SYRINGE             1.0          10  76045012111     DIL012111
# 61         VIAL            20.0          10  65219018420     KET018420
# 62         VIAL            10.0          10  65219018810     KET018810
# 63         VIAL             5.0          10  65219018605          None
# 64      SYRINGE             1.0          10  76045000411     MOR000411
# 65      SYRINGE             1.0          10  76045000511     MOR000511
# 66         VIAL            10.0          10  63323026910     DIP026910
# 67         VIAL            20.0          10  63323026929     DIP026929
# 68         VIAL            50.0          20  63323026950     DIP026950
# 69         VIAL           100.0          10  63323026965     DIP026965
# 70         VIAL             2.0          25  63323001302    THI001302
# 71         VIAL            20.0          25  63323048527     XYL048527
# 72         VIAL            20.0          25  63323048227     XYL048227
# 73         VIAL            20.0          25  63323048327     XYL048327
# 74         VIAL            20.0          25  63323048927    XYL048927
# 75         VIAL             2.0          25  63323049227     XYL049227
# 76         VIAL            30.0          25  63323049237     XYL049237
# 77         VIAL             5.0          25  63323049257     XYL049257
# 78         VIAL             5.0          25  63323049507     XYL049507
# 79         VIAL             2.0          25  63323049527    XYL049527
# 80         VIAL             3.0          25  00143987525     AMI987525
# 81         VIAL             1.0          25   0143951525     DRO951525
# 82         VIAL             2.0          25   0143951425     DRO951425
# 83         VIAL             1.0          25  00641624725     FEN624725
# 84         VIAL             2.0          25  00641602725     FEN602725
# 85         VIAL             5.0          10  00641602810     FEN602810
# 86         VIAL            20.0           1  00641602901     FEN602901
# 87         VIAL            50.0           1  00641603001     FEN603001
# 88         VIAL             1.0          25  00641604425     LOR604425
# 89         VIAL            10.0          10  00641604610          None
# 90         VIAL             1.0          25  00641604525          None
# 91         VIAL            10.0          10  00641604710          None
# 92         VIAL            20.0           1  00641626101          None
# 93         VIAL            50.0           1  00641626201          None
# 94         VIAL            10.0          10  00641614710     STE614710
# 95         VIAL             5.0          12  81298866003     AKF866003
# 96   PLAST. BAG             4.0          10  81298965903     NOR965903
# 97   PLAST. BAG             8.0          10  81298965503     NOR965503
# 98   PLAST. BAG            16.0          10  81298965803     NOR965803
# 99         VIAL            20.0          25  00409488820     SOD488820
# 100        VIAL            50.0          25  00409488850     SOD488850
# 101   CARTRIDGE             2.0          10  00409127332     DIA127332
# 102        VIAL            10.0           1  00009379401     COR379401
# 103   CARTRIDGE             4.0          10  00409233934     LAB233934
# 104   CARTRIDGE             1.0          10  00409198530     LOR198530
# 105        VIAL             1.0           1  61703030906     VIN030906
# 106        VIAL             2.0           1  61703030916     VIN030916
# 107        VIAL             5.0          10  70069036110     SULO36110
# 108        VIAL            10.0          10  70069036210     SULO36210
# 109        VIAL            30.0           1  70069036301     SULO36301
# 110        None             NaN        <NA>         None          None
# 111        None             NaN        <NA>         None          None
# 112        None             NaN        <NA>         None          None
# 113        None             NaN        <NA>         None          None
# 114        None             NaN        <NA>         None          None
# 115        None             NaN        <NA>         None          None
#
#                  product_family
# 0    Methylprednisolone Acetate
# 1    Methylprednisolone Acetate
# 2    Methylprednisolone Acetate
# 3    Methylprednisolone Acetate
# 4          Potassium Phosphates
# 5          Potassium Phosphates
# 6          Potassium Phosphates
# 7            Emergency Syringes
# 8            Emergency Syringes
# 9            Emergency Syringes
# 10           Emergency Syringes
# 11           Emergency Syringes
# 12           Emergency Syringes
# 13           Emergency Syringes
# 14                Cephalosporin
# 15                Cephalosporin
# 16                Cephalosporin
# 17                Cephalosporin
# 18                Cephalosporin
# 19                Cephalosporin
# 20                Cephalosporin
# 21                Cephalosporin
# 22                Cephalosporin
# 23                Cephalosporin
# 24              Dexmedetomidine
# 25              Dexmedetomidine
# 26                   Metoprolol
# 27                      Pitocin
# 28                      Pitocin
# 29              Cupric Chloride
# 30                     Cysteine
# 31            Potassium Acetate
# 32      Sodium Bicarbonate Vial
# 33                Zinc Chloride
# 34                   Bumetanide
# 35                   Bumetanide
# 36                  Bupivacaine
# 37                  Bupivacaine
# 38                  Bupivacaine
# 39                  Bupivacaine
# 40                  Bupivacaine
# 41                  Bupivacaine
# 42                    Cisplatin
# 43                    Cisplatin
# 44                    Cisplatin
# 45                     Diazepam
# 46              Diphenhydramine
# 47              Diphenhydramine
# 48             Fentanyl Syringe
# 49                 Fluorouracil
# 50                 Fluorouracil
# 51                 Fluorouracil
# 52                 Fluorouracil
# 53                      Heparin
# 54                      Heparin
# 55                      Heparin
# 56                      Heparin
# 57                Hydromorphone
# 58                Hydromorphone
# 59                Hydromorphone
# 60                Hydromorphone
# 61                     Ketamine
# 62                     Ketamine
# 63                     Ketamine
# 64                     Morphine
# 65                     Morphine
# 66                     Propofol
# 67                     Propofol
# 68                     Propofol
# 69                     Propofol
# 70                     Thiamine
# 71                    Xylocaine
# 72                    Xylocaine
# 73                    Xylocaine
# 74                    Xylocaine
# 75                    Xylocaine
# 76                    Xylocaine
# 77                    Xylocaine
# 78                    Xylocaine
# 79                    Xylocaine
# 80                   Amiodarone
# 81                   Droperidol
# 82                   Droperidol
# 83                Fentanyl Vial
# 84                Fentanyl Vial
# 85                Fentanyl Vial
# 86                Fentanyl Vial
# 87                Fentanyl Vial
# 88               Lorazepam Vial
# 89               Lorazepam Vial
# 90               Lorazepam Vial
# 91               Lorazepam Vial
# 92               Sodium Acetate
# 93               Sodium Acetate
# 94                Sterile Water
# 95                     Ak-Fluor
# 96               Norepinephrine
# 97               Norepinephrine
# 98               Norepinephrine
# 99              Sodium Chloride
# 100             Sodium Chloride
# 101          Diazepam Cartridge
# 102                   Ibutilide
# 103                   Labetalol
# 104         Lorazepam Carpuject
# 105                 Vincristine
# 106                 Vincristine
# 107                        SMXT
# 108                        SMXT
# 109                        SMXT
# 110                        None
# 111                        None
# 112                        None
# 113                        None
# 114                        None
# 115                        None

# %%
# View the end of a dataset using the .tail() method
extract.tail(1)
# Out:
#     seller generic_name dosage_form  product_volume  uom_detail   ndc  \
# 115   None         None        None             NaN        <NA>  None
#
#     fff_item_code product_family
# 115          None           None

# %%
# See it as plain text
print(extract.head(1))
# Out:
#    seller                generic_name dosage_form  product_volume  uom_detail  \
# 0  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
#
#            ndc fff_item_code              product_family
# 0  70121157301     MET157301  Methylprednisolone Acetate

# %%
# Get a count of the rows
len(extract)
# Out:
# 116

# %%
# or, alternatively, shape returns both row count and column count
extract.shape
# Out:
# (116, 8)

# %%
# or, alternatively, we can get the number of datapoints or cells - the columns times the rows.
extract.size
# Out:
# 928

# %%
# We can use this method to quickly review the datatypes in our dataframe
extract.dtypes
# Out:
# seller             object
# generic_name       object
# dosage_form        object
# product_volume    float64
# uom_detail          Int64
# ndc                object
# fff_item_code      object
# product_family     object
# dtype: object

# %%
# We can use describe to quickly see statistics about our table
extract.describe()
# Out:
#        product_volume  uom_detail
# count      110.000000       110.0
# mean        33.345455   14.627273
# std         76.905182    9.011572
# min          0.500000         1.0
# 25%          2.000000        10.0
# 50%         10.000000        10.0
# 75%         27.500000        25.0
# max        500.000000        25.0

# %%
# We can use info to see another high level summary, including which columns contain nulls, and how many.
extract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   seller          110 non-null    object
#  1   generic_name    110 non-null    object
#  2   dosage_form     110 non-null    object
#  3   product_volume  110 non-null    float64
#  4   uom_detail      110 non-null    Int64
#  5   ndc             110 non-null    object
#  6   fff_item_code   104 non-null    object
#  7   product_family  110 non-null    object
# dtypes: Int64(1), float64(1), object(6)
# memory usage: 7.5+ KB

# %%
# We can return a list of our columns
# Brit likes to copy and paste into copilot to make a CREATE TABLE in Big Query
extract.columns
# Out:
# Index(['seller', 'generic_name', 'dosage_form', 'product_volume', 'uom_detail',
#        'ndc', 'fff_item_code', 'product_family'],
#       dtype='object')

# %%
# Filter data to just product volume above 1;
# Filters data to find whatever you want, so here we are filtering to see how many drugs have more than 1 product available in the product volume on the status frame
more_than_1_product = extract[extract['product_volume'] > 1]
more_than_1_product.head()
# Out:
#       seller          generic_name dosage_form  product_volume  uom_detail  \
# 4     AMNEAL  POTASSIUM PHOSPHATES        VIAL             5.0           5
# 5     AMNEAL  POTASSIUM PHOSPHATES        VIAL            15.0          10
# 6     AMNEAL  POTASSIUM PHOSPHATES        VIAL            50.0          10
# 7  AMPHASTAR      ATROPINE SULFATE     SYRINGE            10.0          10
# 8  AMPHASTAR      CALCIUM CHLORIDE     SYRINGE            10.0          10
#
#            ndc fff_item_code        product_family
# 4  80830169303     POT169303  Potassium Phosphates
# 5  80830169102     POT169102  Potassium Phosphates
# 6  80830169202     POT169202  Potassium Phosphates
# 7  76329334001     ATR334001    Emergency Syringes
# 8  76329330401     CAL330401    Emergency Syringes

# %%
# Filter with more than one condition, such as seller is AMPHASTAR and dosage_form is SYRINGE and product_volume is above 5
more_than_5_product = extract[(extract['seller'] == 'AMPHASTAR') & (extract['dosage_form'] == 'SYRINGE') & (extract['product_volume'] > 5)]
more_than_5_product.head()
# Out:
#        seller            generic_name dosage_form  product_volume  uom_detail  \
# 7   AMPHASTAR        ATROPINE SULFATE     SYRINGE            10.0          10
# 8   AMPHASTAR        CALCIUM CHLORIDE     SYRINGE            10.0          10
# 9   AMPHASTAR  DEXTROSE 50 % IN WATER     SYRINGE            50.0          10
# 10  AMPHASTAR             EPINEPHRINE     SYRINGE            10.0          10
# 13  AMPHASTAR      SODIUM BICARBONATE     SYRINGE            50.0          10
#
#             ndc fff_item_code      product_family
# 7   76329334001     ATR334001  Emergency Syringes
# 8   76329330401     CAL330401  Emergency Syringes
# 9   76329330201     DEX330201  Emergency Syringes
# 10  76329331801     EPI331801  Emergency Syringes
# 13  76329335201     SOD335201  Emergency Syringes

# %%
# Order our last dataframe by highest product_volume
more_than_5_product.sort_values(by='product_volume', ascending=False)
# Out:
#        seller            generic_name dosage_form  product_volume  uom_detail  \
# 9   AMPHASTAR  DEXTROSE 50 % IN WATER     SYRINGE            50.0          10
# 13  AMPHASTAR      SODIUM BICARBONATE     SYRINGE            50.0          10
# 7   AMPHASTAR        ATROPINE SULFATE     SYRINGE            10.0          10
# 8   AMPHASTAR        CALCIUM CHLORIDE     SYRINGE            10.0          10
# 10  AMPHASTAR             EPINEPHRINE     SYRINGE            10.0          10
#
#             ndc fff_item_code      product_family
# 9   76329330201     DEX330201  Emergency Syringes
# 13  76329335201     SOD335201  Emergency Syringes
# 7   76329334001     ATR334001  Emergency Syringes
# 8   76329330401     CAL330401  Emergency Syringes
# 10  76329331801     EPI331801  Emergency Syringes

# %%
# Sort by multiple columns
more_than_5_product.sort_values(by=['generic_name', 'product_volume'], ascending=[True, False])
# Out:
#        seller            generic_name dosage_form  product_volume  uom_detail  \
# 7   AMPHASTAR        ATROPINE SULFATE     SYRINGE            10.0          10
# 8   AMPHASTAR        CALCIUM CHLORIDE     SYRINGE            10.0          10
# 9   AMPHASTAR  DEXTROSE 50 % IN WATER     SYRINGE            50.0          10
# 10  AMPHASTAR             EPINEPHRINE     SYRINGE            10.0          10
# 13  AMPHASTAR      SODIUM BICARBONATE     SYRINGE            50.0          10
#
#             ndc fff_item_code      product_family
# 7   76329334001     ATR334001  Emergency Syringes
# 8   76329330401     CAL330401  Emergency Syringes
# 9   76329330201     DEX330201  Emergency Syringes
# 10  76329331801     EPI331801  Emergency Syringes
# 13  76329335201     SOD335201  Emergency Syringes

# %% [markdown]
# ## Translating Excel to Python

# %% [markdown]
# If you are used to doing most of your work in Excel, the good news is that Python, when using a library like Pandas, is very similar - but more flexible, more powerful, more efficient, and more reusable.
#
# **NOTE** In the real world, not this training exercise, you should do as much work in SQL before moving to python.  Some of this we will be doing using data we obtained from BQ, but it would have been *easier* to do it in SQL -- I am only doing it in Python to show you how it is done.  I usually would only use python for this if the data started OUTSIDE a database and I was working on it before putting it into one.

# %%
# Create new columns by declaring them as a variable on your dataframe.
copy = extract.copy()
copy['new_column'] = 1
copy['next_new_column'] = copy['product_volume'] * copy['uom_detail']
copy['name_and_dosage'] = copy['generic_name'] + ' ' + copy['dosage_form']
copy.head()
# Out:
#    seller                generic_name dosage_form  product_volume  uom_detail  \
# 0  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
# 1  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0          25
# 2  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
# 3  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0          25
# 4  AMNEAL        POTASSIUM PHOSPHATES        VIAL             5.0           5
#
#            ndc fff_item_code              product_family  new_column  \
# 0  70121157301     MET157301  Methylprednisolone Acetate           1
# 1  70121157305     MET157305  Methylprednisolone Acetate           1
# 2  70121157401     MET157401  Methylprednisolone Acetate           1
# 3  70121157405     MET157405  Methylprednisolone Acetate           1
# 4  80830169303     POT169303        Potassium Phosphates           1
#
#    next_new_column                  name_and_dosage
# 0              1.0  METHYLPREDNISOLONE ACETATE VIAL
# 1             25.0  METHYLPREDNISOLONE ACETATE VIAL
# 2              1.0  METHYLPREDNISOLONE ACETATE VIAL
# 3             25.0  METHYLPREDNISOLONE ACETATE VIAL
# 4             25.0        POTASSIUM PHOSPHATES VIAL

# %%
# Delete columns using the drop method Columns
copy = copy.drop(columns=['new_column', 'next_new_column'])
copy.head()
# Out:
#    seller                generic_name dosage_form  product_volume  uom_detail  \
# 0  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
# 1  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0          25
# 2  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
# 3  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0          25
# 4  AMNEAL        POTASSIUM PHOSPHATES        VIAL             5.0           5
#
#            ndc fff_item_code              product_family  \
# 0  70121157301     MET157301  Methylprednisolone Acetate
# 1  70121157305     MET157305  Methylprednisolone Acetate
# 2  70121157401     MET157401  Methylprednisolone Acetate
# 3  70121157405     MET157405  Methylprednisolone Acetate
# 4  80830169303     POT169303        Potassium Phosphates
#
#                    name_and_dosage
# 0  METHYLPREDNISOLONE ACETATE VIAL
# 1  METHYLPREDNISOLONE ACETATE VIAL
# 2  METHYLPREDNISOLONE ACETATE VIAL
# 3  METHYLPREDNISOLONE ACETATE VIAL
# 4        POTASSIUM PHOSPHATES VIAL

# %%
# Group by seller and sum each product_volume
extract.groupby('seller')['product_volume'].sum()
# Out:
# seller
# AMNEAL                         74.0
# AMPHASTAR                     135.5
# APOTEX                        232.0
# BAXTER                        155.0
# ENDO INJECTABLE SOLUTIONS      11.0
# EXELA                         171.0
# FRESENIUS KABI               2535.5
# HIKMA                         186.0
# LONG GROVE                     33.0
# PFIZER                         90.0
# SOMERSET                       45.0
# Name: product_volume, dtype: float64

# %%
# Group by generic_name, dosage_form, and average uom_detail
extract.groupby(['product_family', 'dosage_form'])['uom_detail'].mean()
# Out:
# product_family              dosage_form
# Ak-Fluor                    VIAL               12.0
# Amiodarone                  VIAL               25.0
# Bumetanide                  VIAL               10.0
# Bupivacaine                 VIAL               25.0
# Cephalosporin               VIAL               12.7
# Cisplatin                   VIAL                1.0
# Cupric Chloride             VIAL               25.0
# Cysteine                    VIAL               10.0
# Dexmedetomidine             PLAST. BAG         18.0
# Diazepam                    SYRINGE            24.0
# Diazepam Cartridge          CARTRIDGE          10.0
# Diphenhydramine             SYRINGE            24.0
#                             VIAL               25.0
# Droperidol                  VIAL               25.0
# Emergency Syringes          SYRINGE            10.0
# Fentanyl Syringe            SYRINGE            10.0
# Fentanyl Vial               VIAL               12.4
# Fluorouracil                VIAL                5.5
# Heparin                     IV SOLN            24.0
# Hydromorphone               SYRINGE            10.0
# Ibutilide                   VIAL                1.0
# Ketamine                    VIAL               10.0
# Labetalol                   CARTRIDGE          10.0
# Lorazepam Carpuject         CARTRIDGE          10.0
# Lorazepam Vial              VIAL               17.5
# Methylprednisolone Acetate  VIAL               13.0
# Metoprolol                  VIAL               10.0
# Morphine                    SYRINGE            10.0
# Norepinephrine              PLAST. BAG         10.0
# Pitocin                     VIAL               25.0
# Potassium Acetate           VIAL               25.0
# Potassium Phosphates        VIAL           8.333333
# Propofol                    VIAL               12.5
# SMXT                        VIAL                7.0
# Sodium Acetate              VIAL                1.0
# Sodium Bicarbonate Vial     VIAL               25.0
# Sodium Chloride             VIAL               25.0
# Sterile Water               VIAL               10.0
# Thiamine                    VIAL               25.0
# Vincristine                 VIAL                1.0
# Xylocaine                   VIAL               25.0
# Zinc Chloride               VIAL               25.0
# Name: uom_detail, dtype: Float64

# %%
# You can pivot your table in pandas
# Create a pivot table
pivot_table = extract.pivot_table(
    index='seller',
    columns='dosage_form',
    values='ndc',
    aggfunc='count',
    fill_value=0   # fill in missing values with 0
)

# Display the pivot table
pivot_table
# Out:
# dosage_form                CARTRIDGE  IV SOLN  PLAST. BAG  SYRINGE  VIAL
# seller
# AMNEAL                             0        0           0        0     7
# AMPHASTAR                          0        0           0        7     0
# APOTEX                             0        0           0        0    10
# BAXTER                             0        0           2        0     1
# ENDO INJECTABLE SOLUTIONS          0        0           0        0     2
# EXELA                              0        0           0        0     5
# FRESENIUS KABI                     0        4           0        9    33
# HIKMA                              0        0           0        0    15
# LONG GROVE                         0        0           3        0     1
# PFIZER                             3        0           0        0     5
# SOMERSET                           0        0           0        0     3

# %%
# Handle Missing Values - if NULL in uom_detail enter 1
copy['uom_detail'] = copy['uom_detail'].fillna(1)
copy.head()
# Out:
#    seller                generic_name dosage_form  product_volume  uom_detail  \
# 0  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
# 1  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0          25
# 2  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
# 3  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0          25
# 4  AMNEAL        POTASSIUM PHOSPHATES        VIAL             5.0           5
#
#            ndc fff_item_code              product_family  \
# 0  70121157301     MET157301  Methylprednisolone Acetate
# 1  70121157305     MET157305  Methylprednisolone Acetate
# 2  70121157401     MET157401  Methylprednisolone Acetate
# 3  70121157405     MET157405  Methylprednisolone Acetate
# 4  80830169303     POT169303        Potassium Phosphates
#
#                    name_and_dosage
# 0  METHYLPREDNISOLONE ACETATE VIAL
# 1  METHYLPREDNISOLONE ACETATE VIAL
# 2  METHYLPREDNISOLONE ACETATE VIAL
# 3  METHYLPREDNISOLONE ACETATE VIAL
# 4        POTASSIUM PHOSPHATES VIAL

# %%
# Drop any rows where any value is null
copy = copy.dropna()
copy.head()
# Out:
#    seller                generic_name dosage_form  product_volume  uom_detail  \
# 0  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
# 1  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0          25
# 2  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
# 3  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0          25
# 4  AMNEAL        POTASSIUM PHOSPHATES        VIAL             5.0           5
#
#            ndc fff_item_code              product_family  \
# 0  70121157301     MET157301  Methylprednisolone Acetate
# 1  70121157305     MET157305  Methylprednisolone Acetate
# 2  70121157401     MET157401  Methylprednisolone Acetate
# 3  70121157405     MET157405  Methylprednisolone Acetate
# 4  80830169303     POT169303        Potassium Phosphates
#
#                    name_and_dosage
# 0  METHYLPREDNISOLONE ACETATE VIAL
# 1  METHYLPREDNISOLONE ACETATE VIAL
# 2  METHYLPREDNISOLONE ACETATE VIAL
# 3  METHYLPREDNISOLONE ACETATE VIAL
# 4        POTASSIUM PHOSPHATES VIAL

# %%
# Drop any row where the ndc specifically is null
copy = copy.dropna(subset=['ndc'])
copy.head()
# Out:
#    seller                generic_name dosage_form  product_volume  uom_detail  \
# 0  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
# 1  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0          25
# 2  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
# 3  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0          25
# 4  AMNEAL        POTASSIUM PHOSPHATES        VIAL             5.0           5
#
#            ndc fff_item_code              product_family  \
# 0  70121157301     MET157301  Methylprednisolone Acetate
# 1  70121157305     MET157305  Methylprednisolone Acetate
# 2  70121157401     MET157401  Methylprednisolone Acetate
# 3  70121157405     MET157405  Methylprednisolone Acetate
# 4  80830169303     POT169303        Potassium Phosphates
#
#                    name_and_dosage
# 0  METHYLPREDNISOLONE ACETATE VIAL
# 1  METHYLPREDNISOLONE ACETATE VIAL
# 2  METHYLPREDNISOLONE ACETATE VIAL
# 3  METHYLPREDNISOLONE ACETATE VIAL
# 4        POTASSIUM PHOSPHATES VIAL

# %% [markdown]
# In Excel you might use XLOOKUP, VLOOKUP, HLOOKUP to combine data,
#
# In SQL you use joins or unions to combine data.
#
# In Pandas, we will be using merge and concatenate to combine data.

# %%
# Join the extract to the mtd (mtd on left) so that the product_family is returned, use ndc for join
merged_df = pd.merge(mtd, extract[['ndc', 'product_family']], on='ndc', how='left')

# Display the resulting DataFrame
merged_df.tail(5)
# Out:
#                          fff_facility_name fff_facility_id  \
# 34999  Baptist Medical Center Jacksonville        FFL02646
# 35000   Avera Pharmacy Distribution Center       FSD366893
# 35001   Avera Pharmacy Distribution Center       FSD366893
# 35002   Avera Pharmacy Distribution Center       FSD366893
# 35003   Avera Pharmacy Distribution Center       FSD366893
#
#       fff_health_system_name fff_health_system_id fff_item_number  \
# 34999          BAPTIST - PGX           ML30000132       ZIN010204
# 35000       AVERA HEALTH PGX           ML30000191       ZIN010204
# 35001       AVERA HEALTH PGX           ML30000191       ZIN010204
# 35002       AVERA HEALTH PGX           ML30000191       ZIN010204
# 35003       AVERA HEALTH PGX           ML30000191       ZIN010204
#
#                   fff_item_description firm_allocations_indicator  \
# 34999  ZINC CHLORIDE INJ 25/PK - EXELA                       None
# 35000  ZINC CHLORIDE INJ 25/PK - EXELA                       None
# 35001  ZINC CHLORIDE INJ 25/PK - EXELA                       None
# 35002  ZINC CHLORIDE INJ 25/PK - EXELA                       None
# 35003  ZINC CHLORIDE INJ 25/PK - EXELA                       None
#
#       regional_director territory_manager              sdr valid_start_date  \
# 34999    Robert Grzenda      Jackie David     Jackie David       2025-01-01
# 35000    Terri St. John      Steve Patton  Cindy Gutierrez       2025-01-01
# 35001    Terri St. John      Steve Patton  Cindy Gutierrez       2025-01-01
# 35002    Terri St. John      Steve Patton  Cindy Gutierrez       2025-01-01
# 35003    Terri St. John      Steve Patton  Cindy Gutierrez       2025-01-01
#
#                  ndc  annual_commitment  monthly_allocation  \
# 34999  51754-0102-04                 24                   2
# 35000  51754-0102-04                  3                <NA>
# 35001  51754-0102-04                  3                <NA>
# 35002  51754-0102-04                  3                <NA>
# 35003  51754-0102-04                  3                <NA>
#
#        monthly_remaining  ytd_total  percent_compliant  \
# 34999                  2          8              33.33
# 35000               <NA>          3             100.00
# 35001               <NA>          3             100.00
# 35002               <NA>          3             100.00
# 35003               <NA>          3             100.00
#
#        actual_purchased_units purchase_month product_family
# 34999                       2     2025-04-01            NaN
# 35000                       1     2025-01-01            NaN
# 35001                       1     2025-02-01            NaN
# 35002                    <NA>     2025-03-01            NaN
# 35003                       1     2025-04-01            NaN

# %%
# Join the extract to the mtd (mtd on left) so that the product_family is returned, use fff_item_number and fff_item_code for join
merged_df = pd.merge(mtd, extract[['fff_item_code', 'product_family']], left_on='fff_item_number', right_on='fff_item_code', how='left')

# Display the resulting DataFrame
merged_df.tail(5)
# Out:
#                          fff_facility_name fff_facility_id  \
# 34999  Baptist Medical Center Jacksonville        FFL02646
# 35000   Avera Pharmacy Distribution Center       FSD366893
# 35001   Avera Pharmacy Distribution Center       FSD366893
# 35002   Avera Pharmacy Distribution Center       FSD366893
# 35003   Avera Pharmacy Distribution Center       FSD366893
#
#       fff_health_system_name fff_health_system_id fff_item_number  \
# 34999          BAPTIST - PGX           ML30000132       ZIN010204
# 35000       AVERA HEALTH PGX           ML30000191       ZIN010204
# 35001       AVERA HEALTH PGX           ML30000191       ZIN010204
# 35002       AVERA HEALTH PGX           ML30000191       ZIN010204
# 35003       AVERA HEALTH PGX           ML30000191       ZIN010204
#
#                   fff_item_description firm_allocations_indicator  \
# 34999  ZINC CHLORIDE INJ 25/PK - EXELA                       None
# 35000  ZINC CHLORIDE INJ 25/PK - EXELA                       None
# 35001  ZINC CHLORIDE INJ 25/PK - EXELA                       None
# 35002  ZINC CHLORIDE INJ 25/PK - EXELA                       None
# 35003  ZINC CHLORIDE INJ 25/PK - EXELA                       None
#
#       regional_director territory_manager              sdr valid_start_date  \
# 34999    Robert Grzenda      Jackie David     Jackie David       2025-01-01
# 35000    Terri St. John      Steve Patton  Cindy Gutierrez       2025-01-01
# 35001    Terri St. John      Steve Patton  Cindy Gutierrez       2025-01-01
# 35002    Terri St. John      Steve Patton  Cindy Gutierrez       2025-01-01
# 35003    Terri St. John      Steve Patton  Cindy Gutierrez       2025-01-01
#
#                  ndc  annual_commitment  monthly_allocation  \
# 34999  51754-0102-04                 24                   2
# 35000  51754-0102-04                  3                <NA>
# 35001  51754-0102-04                  3                <NA>
# 35002  51754-0102-04                  3                <NA>
# 35003  51754-0102-04                  3                <NA>
#
#        monthly_remaining  ytd_total  percent_compliant  \
# 34999                  2          8              33.33
# 35000               <NA>          3             100.00
# 35001               <NA>          3             100.00
# 35002               <NA>          3             100.00
# 35003               <NA>          3             100.00
#
#        actual_purchased_units purchase_month fff_item_code product_family
# 34999                       2     2025-04-01     ZIN010204  Zinc Chloride
# 35000                       1     2025-01-01     ZIN010204  Zinc Chloride
# 35001                       1     2025-02-01     ZIN010204  Zinc Chloride
# 35002                    <NA>     2025-03-01     ZIN010204  Zinc Chloride
# 35003                       1     2025-04-01     ZIN010204  Zinc Chloride

# %%
# Concatenate extract and mtd along rows (axis=0) - this lets youcombine files with the same headers one on top of another
# This is like union all in SQL
copy1 = extract.copy()
copy2 = extract.copy()
concatenated_df = pd.concat([copy1, copy2], axis=0)

# Show length of frames
print(len(copy1))
print(len(copy2))
print(len(concatenated_df))
# Out:
# 116
# 116
# 232

# %%
# Remove duplicates based on 'ndc' column in extract
extract_unique_ndc = copy.drop_duplicates(subset=['ndc'])

# Display the resulting DataFrames
extract_unique_ndc.head()
# Out:
#    seller                generic_name dosage_form  product_volume  uom_detail  \
# 0  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
# 1  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0          25
# 2  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
# 3  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0          25
# 4  AMNEAL        POTASSIUM PHOSPHATES        VIAL             5.0           5
#
#            ndc fff_item_code              product_family  \
# 0  70121157301     MET157301  Methylprednisolone Acetate
# 1  70121157305     MET157305  Methylprednisolone Acetate
# 2  70121157401     MET157401  Methylprednisolone Acetate
# 3  70121157405     MET157405  Methylprednisolone Acetate
# 4  80830169303     POT169303        Potassium Phosphates
#
#                    name_and_dosage
# 0  METHYLPREDNISOLONE ACETATE VIAL
# 1  METHYLPREDNISOLONE ACETATE VIAL
# 2  METHYLPREDNISOLONE ACETATE VIAL
# 3  METHYLPREDNISOLONE ACETATE VIAL
# 4        POTASSIUM PHOSPHATES VIAL

# %% [markdown]
# ## Save Files

# %% [markdown]
# You can easily save anything you make in Colab/python as a file, or even send it to BigQuery.  However, we will not be pushing up to BQ yet - that can be a future lesson ;)
#
# The files will download to COLAB - make sure you download them from here to your computer! The storage is not durable and will expire quickly.

# %%
# Save extract to csv
extract.to_csv('extract.csv', index=False)

# Save extract to xlsx
extract.to_excel('extract.xlsx', index=False)

# Save extract, mtd on two different sheets in an xlsx
with pd.ExcelWriter('multiple_sheets.xlsx') as writer:
    extract.to_excel(writer, sheet_name='extract', index=False)
    mtd.to_excel(writer, sheet_name='mtd', index=False)

# %%
extract.head()
# Out:
#    seller                generic_name dosage_form  product_volume  uom_detail  \
# 0  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
# 1  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0          25
# 2  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0           1
# 3  AMNEAL  METHYLPREDNISOLONE ACETATE        VIAL             1.0          25
# 4  AMNEAL        POTASSIUM PHOSPHATES        VIAL             5.0           5
#
#            ndc fff_item_code              product_family
# 0  70121157301     MET157301  Methylprednisolone Acetate
# 1  70121157305     MET157305  Methylprednisolone Acetate
# 2  70121157401     MET157401  Methylprednisolone Acetate
# 3  70121157405     MET157405  Methylprednisolone Acetate
# 4  80830169303     POT169303        Potassium Phosphates

# %% [markdown]
# ## Visualize the Data

# %% [markdown]
# # Examples from My Work
#
# Bringing it all together :)
#
# Think of each piece you learned as a tool you can use to solve problems. Mix and match depending on the puzzle at hand.

# %% [markdown]
# ## Spreadsheet -> SQL Insert Script Converter
#
# The code block below was written to convert a csv to a SQL script to speed up bulk inserts into MS SQL Server for the compounding team's power app.

# %%
import pandas as pd

def convert_dtype(value, dtype):
    if pd.isnull(value):
        return "NULL"
    if dtype.startswith('VARCHAR') or dtype.startswith('CHAR'):
        if dtype == 'CHAR(13)' and isinstance(value, (float, int)):
            value = str(int(value)).zfill(13)  # Ensure it's a 13-character string
        elif dtype == 'CHAR(13)' and isinstance(value, str):
            value = value.split('.').zfill(13)  # Remove trailing .0 or .00
        return f"'{value}'"
    if dtype == 'BIT':
        return str(int(value))
    if dtype == 'DATE':
        return f"'{value}'"
    return str(value)

def df_to_sql_insert(df, table_name, schema):
    chunk_size = 999
    num_chunks = (len(df) // chunk_size) + 1

    for chunk_num in range(num_chunks):
        start_row = chunk_num * chunk_size
        end_row = min((chunk_num + 1) * chunk_size, len(df))

        sql_script = f"INSERT INTO {table_name} ("
        sql_script += ", ".join(df.columns) + ") VALUES\n"

        values = []
        for index, row in df.iloc[start_row:end_row].iterrows():
            row_values = []
            for col in df.columns:
                value = row[col]
                dtype = schema.get(col, 'VARCHAR(100)')  # Default to VARCHAR(100) if column not in schema
                row_values.append(convert_dtype(value, dtype))
            values.append("(" + ", ".join(row_values) + ")")

        sql_script += ",\n".join(values) + ";"

        # Save the SQL script to a file
        file_path = f'insert_script_chunk_{chunk_num + 1}.sql'
        with open(file_path, 'w') as f:
            f.write(sql_script)

        print(f"SQL script chunk {chunk_num + 1} has been successfully created and saved to {file_path}.")

    return sql_script

production_status_datatypes = {
    'status_id': 'INT IDENTITY(1,1) PRIMARY KEY',  # Set as identity column
    'ndc': 'CHAR(11)',
    'production_status': 'VARCHAR(50)',
    'start_date': 'DATE',
    'end_date': 'DATE',
    'FK_status_products': 'FOREIGN KEY (ndc) REFERENCES dbo.Products(ndc)'
}


# Read in CSV file
data = pd.read_csv('productstatus.csv')


table_name = 'dbo.production_status'
sql_script = df_to_sql_insert(data, table_name, production_status_datatypes)

print(sql_script)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-81-83d4503349f3> in <cell line: 0>()
#      58
#      59 # Read in CSV file
# ---> 60 data = pd.read_csv('productstatus.csv')
#      61
#      62
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'productstatus.csv'

# %% [markdown]
# ## Combine 100s of Excel Files
#
# This file is used to take a folder with hundreds or thousands of excel files that have the same columns, minus one which has a different month name each time.  It combines all of the files, and fixes the one column that is an issue.
#
# https://github.com/premierBrittany/FTS_Database/blob/main/FTS_Union_Experiment_v2_2023.ipynb

# %% [markdown]
# ## Admin Fee File Validation & Logging
#
# This file contains code that can parse an Admin Fee File, apply quality rules, annotate each row if there is an issue with custom error messages, and then log data about the file itself to BigQuery.
#
# https://github.com/premierBrittany/503B_Admin_Fee_Validation/blob/main/Admin_Fee_Validator.ipynb

# %% [markdown]
# ## PGx Monthly Compliance Dashboard Refresher
#
# The code in this notebook takes a spreadsheet from a vendor and transforms it for analytics by iterating through various monthly columns to create a single column for the amount of product purchased, and a column for the month the purchase belongs in.  It then combines those together.  This creates a "vertical" dataframe for analysis.  We can now analyse the purchases over time.
#
# This code also pushes the data to BigQuery, where it can power dashboards and other analytics.
#
# https://github.com/premierBrittany/PGx_FFF_Ingestion_Pipelines/blob/main/PGx_FFF_Monthly_Compliance_Refresher.ipynb
